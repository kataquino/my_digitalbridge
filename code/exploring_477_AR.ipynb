# %%
import pandas as pd

# %%
df_ar = pd.read_csv('/Users/katherineaquino/Downloads/AR-Fixed-Dec2019-v1.csv')

# %%
df_ar.head()
# Out:
#    LogRecNo  Provider_Id      FRN                  ProviderName      DBAName  \
# 0     26175        53788  3723822  Level  3 Communications, LLC  CenturyLink
# 1     26176        53788  3723822  Level  3 Communications, LLC  CenturyLink
# 2     26177        53788  3723822  Level  3 Communications, LLC  CenturyLink
# 3     26178        53788  3723822  Level  3 Communications, LLC  CenturyLink
# 4     26179        53788  3723822  Level  3 Communications, LLC  CenturyLink
#
#   HoldingCompanyName  HocoNum          HocoFinal StateAbbr       BlockCode  \
# 0  CenturyLink, Inc.   130228  CenturyLink, Inc.        AR  50014802001218
# 1  CenturyLink, Inc.   130228  CenturyLink, Inc.        AR  50014802002115
# 2  CenturyLink, Inc.   130228  CenturyLink, Inc.        AR  50014802002120
# 3  CenturyLink, Inc.   130228  CenturyLink, Inc.        AR  50014802002159
# 4  CenturyLink, Inc.   130228  CenturyLink, Inc.        AR  50014803001020
#
#    TechCode  Consumer  MaxAdDown  MaxAdUp  Business
# ...
